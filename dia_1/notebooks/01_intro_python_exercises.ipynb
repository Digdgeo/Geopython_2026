# %% [markdown]
# # GeoPython 2026 — Día 1: Ejercicios de Python
#
# **Curso de Análisis Espacial con Python**
# Gabinete de Formación del CSIC — Estación Biológica de Doñana, Sevilla
#
# ---
#
# > Completa las celdas marcadas con `# TU CÓDIGO AQUÍ`.
# >
# > - ⭐ Fácil — repaso directo del notebook
# > - ⭐⭐ Medio — combina varios conceptos
# > - ⭐⭐⭐ Difícil — requiere pensar la solución
#
# ---

# %% [markdown]
# ## Bloque 1 — Strings ⭐

# %% [markdown]
# ### Ejercicio 1.1 ⭐
# Dada la ruta de un archivo, extrae el nombre del archivo (con extensión), la extensión sola y el nombre sin extensión.
# **Sin usar** `os.path` ni `pathlib` — solo métodos de string.

# %%
ruta = '/home/usuario/datos/canarias/tenerife_municipios.shp'

nombre_archivo = # TU CÓDIGO AQUÍ   → 'tenerife_municipios.shp'
extension      = # TU CÓDIGO AQUÍ   → '.shp'
nombre_sin_ext = # TU CÓDIGO AQUÍ   → 'tenerife_municipios'

print(nombre_archivo)
print(extension)
print(nombre_sin_ext)

# %% [markdown]
# ### Ejercicio 1.2 ⭐
# Dado el string de abajo, construye un nuevo string con solo las palabras que empiezan por mayúscula, separadas por coma y espacio.

# %%
texto = 'análisis Espacial con Python en Sevilla con Geopandas y Rasterio'

# Resultado esperado: 'Espacial, Python, Sevilla, Geopandas, Rasterio'
resultado = # TU CÓDIGO AQUÍ

print(resultado)

# %% [markdown]
# ### Ejercicio 1.3 ⭐⭐
# Escribe una función que reciba un string con palabras separadas por espacios y devuelva el mismo string con cada palabra en formato *Title Case* (primera letra mayúscula, resto minúscula), **sin usar** `.title()`.
# Ejemplo: `'hOLA mUnDo'` → `'Hola Mundo'`

# %%
def title_case_manual(s: str) -> str:
    """
    Convierte cada palabra a Title Case sin usar .title().
    """
    # TU CÓDIGO AQUÍ
    pass


print(title_case_manual('hOLA mUnDo'))           # → 'Hola Mundo'
print(title_case_manual('análisis espacial'))     # → 'Análisis Espacial'
print(title_case_manual('GEOPYTHON 2026'))        # → 'Geopython 2026'

# %% [markdown]
# ---
# ## Bloque 2 — Colecciones ⭐⭐

# %% [markdown]
# ### Ejercicio 2.1 ⭐
# Dada la lista de archivos, crea un diccionario que agrupe los nombres por extensión.

# %%
archivos = [
    'municipios.shp', 'rios.shp', 'parcelas.gpkg',
    'puntos.geojson', 'carreteras.shp',
    'cobertura.gpkg', 'estaciones.geojson'
]

# Resultado: {'.shp': [...], '.gpkg': [...], '.geojson': [...]}
por_extension = # TU CÓDIGO AQUÍ

for ext, nombres in por_extension.items():
    print(f'{ext}: {nombres}')

# %% [markdown]
# ### Ejercicio 2.2 ⭐⭐
# Tienes dos listas: nombres de islas y sus áreas. Crea una lista de tuplas `(nombre, area)` ordenada de mayor a menor área y muestra solo las 3 primeras.

# %%
nombres = ['El Hierro', 'Tenerife', 'La Gomera', 'Gran Canaria',
           'Lanzarote', 'La Palma', 'Fuerteventura']
areas   = [268, 2034, 370, 1560, 846, 708, 1660]

islas_ordenadas = # TU CÓDIGO AQUÍ

print('Las 3 islas más grandes:')
# TU CÓDIGO AQUÍ

# %% [markdown]
# ### Ejercicio 2.3 ⭐⭐
# Dado el diccionario de puntos GPS, encuentra los que tienen coordenadas duplicadas (mismo punto, distinto nombre).

# %%
puntos_gps = {
    'P001': (28.4636, -16.2518),
    'P002': (28.1235, -15.4360),
    'P003': (28.4636, -16.2518),   # duplicado de P001
    'P004': (29.0469, -13.5899),
    'P005': (28.1235, -15.4360),   # duplicado de P002
    'P006': (27.7212, -18.0328),
}

# Encuentra e imprime los grupos de puntos con coordenadas duplicadas
# TU CÓDIGO AQUÍ

# %% [markdown]
# ---
# ## Bloque 3 — Funciones ⭐⭐

# %% [markdown]
# ### Ejercicio 3.1 ⭐
# Escribe una función `contar_tipos` que reciba una lista con elementos mezclados y devuelva un diccionario con el conteo de cada tipo (`int`, `float`, `str`, `list`, etc.).

# %%
def contar_tipos(lista: list) -> dict:
    """
    Cuenta cuántos elementos hay de cada tipo en la lista.

    Returns:
        dict: {nombre_tipo: conteo}
    """
    # TU CÓDIGO AQUÍ
    pass


datos = [1, 'hola', 3.14, [1, 2], 42, 'mundo', 2.71, {'a': 1}, True]
print(contar_tipos(datos))
# Resultado esperado: {'int': 3, 'str': 2, 'float': 2, 'list': 1, 'dict': 1}

# %% [markdown]
# ### Ejercicio 3.2 ⭐⭐
# Escribe una función `aplanar` que convierta una lista de listas (anidada 1 nivel) en una lista plana.
# Hazlo en **una sola línea** usando comprensión de listas.

# %%
def aplanar(lista_de_listas: list) -> list:
    """
    Aplana una lista de listas en una sola lista.
    Implementa en una sola línea con comprensión.
    """
    # TU CÓDIGO AQUÍ (una sola línea)
    pass


entrada = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]
print(aplanar(entrada))   # [1, 2, 3, 4, 5, 6, 7, 8, 9]

bandas = [['B2', 'B3', 'B4'], ['B8'], ['B11', 'B12']]
print(aplanar(bandas))    # ['B2', 'B3', 'B4', 'B8', 'B11', 'B12']

# %% [markdown]
# ### Ejercicio 3.3 ⭐⭐
# Escribe una función `estadisticas` que reciba una lista de números y devuelva un diccionario con `n`, `media`, `mediana`, `min` y `max`.
# Calcula la **mediana sin usar** `statistics.median`.

# %%
def estadisticas(valores: list) -> dict:
    """
    Calcula estadísticas descriptivas básicas.

    Args:
        valores: lista de números

    Returns:
        dict con: n, media, mediana, min, max

    Raises:
        ValueError: si la lista está vacía
    """
    # TU CÓDIGO AQUÍ
    pass


print(estadisticas([3, 1, 4, 1, 5, 9, 2, 6]))
print(estadisticas([7]))           # caso con un solo elemento

try:
    estadisticas([])
except ValueError as e:
    print(f'Error: {e}')

# %% [markdown]
# ### Ejercicio 3.4 ⭐⭐⭐
# Escribe una función `distancia_haversine` que calcule la distancia en kilómetros entre dos puntos geográficos.
#
# $$d = 2R \cdot \arcsin\!\left(\sqrt{\sin^2\!\frac{\Delta\phi}{2} + \cos\phi_1\cos\phi_2\sin^2\!\frac{\Delta\lambda}{2}}\right)$$
#
# Donde $R = 6371$ km, $\phi$ = latitud, $\lambda$ = longitud (en radianes).

# %%
import math

def distancia_haversine(lat1: float, lon1: float,
                        lat2: float, lon2: float) -> float:
    """
    Distancia en km entre dos puntos sobre la esfera terrestre.
    """
    # TU CÓDIGO AQUÍ
    pass


# EBD (Doñana) → Teide
print(f'EBD → Teide:          {distancia_haversine(37.3891, -5.9845, 28.2723, -16.6431):.1f} km')  # ~1618
# Sevilla → Madrid
print(f'Sevilla → Madrid:     {distancia_haversine(37.3891, -5.9845, 40.4168, -3.7038):.1f} km')   # ~390

# %% [markdown]
# ---
# ## Bloque 4 — Clases ⭐⭐⭐
#
# ### Ejercicio 4.1 ⭐⭐
# Crea una clase `Pila` (stack) que implemente la estructura de datos LIFO.
# Debe tener: `apilar(elem)`, `desapilar()`, `ver_tope()`, `esta_vacia()`, `__len__`, `__str__`.

# %%
class Pila:
    """
    Estructura de datos LIFO (Last In, First Out).
    """

    def __init__(self):
        # TU CÓDIGO AQUÍ
        pass

    def apilar(self, elemento) -> None:
        """Añade un elemento en el tope de la pila."""
        # TU CÓDIGO AQUÍ
        pass

    def desapilar(self):
        """Elimina y devuelve el elemento del tope. Error si está vacía."""
        # TU CÓDIGO AQUÍ
        pass

    def ver_tope(self):
        """Devuelve el tope sin eliminarlo."""
        # TU CÓDIGO AQUÍ
        pass

    def esta_vacia(self) -> bool:
        # TU CÓDIGO AQUÍ
        pass

    def __len__(self) -> int:
        # TU CÓDIGO AQUÍ
        pass

    def __str__(self) -> str:
        # TU CÓDIGO AQUÍ
        pass


# Tests
p = Pila()
print(f'Vacía: {p.esta_vacia()}')   # True

for item in ['archivo_1.shp', 'archivo_2.shp', 'archivo_3.gpkg']:
    p.apilar(item)

print(p)                            # muestra los elementos
print(f'Tope: {p.ver_tope()}')      # archivo_3.gpkg
print(f'Tamaño: {len(p)}')          # 3
print(f'Desapilado: {p.desapilar()}')
print(f'Tamaño: {len(p)}')          # 2

# %% [markdown]
# ### Ejercicio 4.2 ⭐⭐⭐
# Crea una clase `Matriz2D` que represente una matriz matemática de tamaño `n×m`.
# Debe soportar:
# - Acceso por índices: `m[i][j]`
# - Suma de matrices: `m1 + m2`
# - Multiplicación escalar: `m * 3`
# - Transposición: `m.transponer()`
# - `__str__` que la imprima de forma legible

# %%
class Matriz2D:
    """
    Matriz matemática de tamaño filas x columnas.
    """

    def __init__(self, filas: int, columnas: int, datos=None):
        """
        Args:
            filas, columnas: dimensiones
            datos: lista de listas (opcional). Si es None, se inicializa a 0.
        """
        # TU CÓDIGO AQUÍ
        pass

    def __getitem__(self, idx):
        """Permite acceder con m[i] (devuelve la fila i)."""
        # TU CÓDIGO AQUÍ
        pass

    def __add__(self, otra: 'Matriz2D') -> 'Matriz2D':
        """Suma elemento a elemento. Las dimensiones deben coincidir."""
        # TU CÓDIGO AQUÍ
        pass

    def __mul__(self, escalar: float) -> 'Matriz2D':
        """Multiplicación por escalar."""
        # TU CÓDIGO AQUÍ
        pass

    def transponer(self) -> 'Matriz2D':
        """Devuelve la transpuesta (filas ↔ columnas)."""
        # TU CÓDIGO AQUÍ
        pass

    def __str__(self) -> str:
        # TU CÓDIGO AQUÍ
        pass

    def __repr__(self) -> str:
        return f'Matriz2D({self.filas}x{self.columnas})'


# Tests
m1 = Matriz2D(2, 3, [[1, 2, 3], [4, 5, 6]])
m2 = Matriz2D(2, 3, [[7, 8, 9], [1, 2, 3]])

print('M1:')
print(m1)

print('M1 + M2:')
print(m1 + m2)

print('M1 * 2:')
print(m1 * 2)

print('Transpuesta de M1:')
print(m1.transponer())

print(f'Acceso m1[0][2]: {m1[0][2]}')   # 3

# %% [markdown]
# ---
# ## Reto final ⭐⭐⭐ — Rock, Paper, Scissors, Lizard, Spock
#
# En clase hemos visto la solución con `if/elif`. Ahora refactorizala usando un **diccionario**
# y añade una función `play()` que gestione el flujo del juego.
#
# **Recuerda la tabla de números:**
#
# | Rock | Spock | Paper | Lizard | Scissors |
# |------|-------|-------|--------|----------|
# | 0    | 1     | 2     | 3      | 4        |
#
# `(comp - jugador) % 5 >= 3` → gana el jugador.

# %%
import random

# Sustituye los if/elif por un diccionario
d = # TU CÓDIGO AQUÍ   →  {'Rock': 0, 'Spock': 1, ...}

def number_to_name(number):
    # TU CÓDIGO AQUÍ
    pass

def name_to_number(name):
    # TU CÓDIGO AQUÍ
    pass

def rpsls(guess):
    # TU CÓDIGO AQUÍ
    # 1. Convierte guess a número
    # 2. Genera número aleatorio para la máquina
    # 3. Calcula (comp - jugador) % 5
    # 4. Imprime elecciones y resultado
    pass

def play():
    # TU CÓDIGO AQUÍ
    # 1. Pide la elección al jugador con input()
    # 2. Llama a rpsls()
    # 3. Pregunta si quiere jugar otra vez y gestiona la respuesta
    pass

play()

# %% [markdown]
# ---
# ## Resumen de ejercicios
#
# | # | Ejercicio | Conceptos clave | Dificultad |
# |---|-----------|-----------------|------------|
# | 1.1 | Parsear ruta sin os.path | slicing, split, rsplit | ⭐ |
# | 1.2 | Filtrar palabras con mayúscula | split, comprensión, join | ⭐ |
# | 1.3 | Title case manual | split, capitalize, join | ⭐⭐ |
# | 2.1 | Agrupar por extensión | dict, setdefault/get | ⭐ |
# | 2.2 | Ordenar islas por área | zip, sorted, lambda | ⭐⭐ |
# | 2.3 | GPS duplicados | dict inverso, grupos | ⭐⭐ |
# | 3.1 | Contar tipos | type(), dict | ⭐ |
# | 3.2 | Aplanar lista en una línea | comprensión anidada | ⭐⭐ |
# | 3.3 | Estadísticas con mediana | sorted, funciones | ⭐⭐ |
# | 3.4 | Distancia Haversine | math, funciones, type hints | ⭐⭐⭐ |
# | 4.1 | Clase Pila | `__len__`, `__str__`, raise | ⭐⭐ |
# | 4.2 | Clase Matriz2D | `__add__`, `__mul__`, `__getitem__` | ⭐⭐⭐ |
# | Final | RPSLSP completo | todo: funciones, clases, herencia | ⭐⭐⭐ |
#
# ---
# *GeoPython 2026 — CSIC / Estación Biológica de Doñana*
